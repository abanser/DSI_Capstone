# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bokeh.plotting import figure, output_file, show, ColumnDataSource
from bokeh.models import HoverTool
from bokeh.io import output_notebook
from bokeh.models import NumeralTickFormatter
import seaborn as sns
from scipy import stats
from IPython.display import HTML

sns.set(style="ticks", color_codes=True,font_scale=1.5)
engine = create_engine('postgresql://tom:jerry@mydbs.cahzu59qwcbo.us-east-2.rds.amazonaws.com:5432/strava_zillow')

# %% [markdown]
# I collected data from 33 metro areas.
#
# I culled out all but 4 cities for my analysis for various reasons

# %% [markdown]
# ## Why I rejected some metro areas
#
# - Skewed distrubition of segment counts per zip code

# %%
query = """WITH t1 AS (SELECT zipcode, count(zipcode) as segct, sum(segment_details.athlete_count) as segathct
FROM segment
INNER JOIN segment_details
ON segment.seg_id = segment_details.seg_id
GROUP BY zipcode),
t2 AS (SELECT zipcode, y_2016
FROM zipstats),
t3 AS (SELECT zipcode, metro,zhvi
FROM zillow_zhvi
ORDER BY zipcode)
SELECT t1.zipcode, t1.segct, t1.segathct, (t1.segct*t1.segathct)/cast(t2.y_2016 as decimal) as percapita_segusers, t1.segct/cast(t2.y_2016 as decimal) as percapita_segs, t2.y_2016, t3.metro, t3.zhvi as med_price
FROM t1
INNER JOIN t2
ON t1.zipcode = t2.zipcode 
INNER JOIN t3
ON t3.zipcode = t2.zipcode
WHERE metro in ('New York','Austin', 'Seattle','San Diego', 'Rochester')
ORDER BY zipcode DESC;"""

# %%
df_all = pd.read_sql_query(query,con=engine)
fig, ax = plt.subplots()
fig.set_size_inches(14, 9)
g=sns.violinplot(x="metro", y="segct",data=df_all, inner="box", ax=ax) 
g.set_xlabel('Metro', fontsize=18)
g.set_ylabel('# of segments per zipcode', fontsize=18)
plt.show()

# %% [markdown]
# - Few zip codes with segments

# %%
query = """WITH t1 AS (SELECT zipcode, count(zipcode) as segct, sum(segment_details.athlete_count) as segathct
FROM segment
INNER JOIN segment_details
ON segment.seg_id = segment_details.seg_id
GROUP BY zipcode),
t2 AS (SELECT zipcode, y_2016
FROM zipstats),
t3 AS (SELECT zipcode, metro,zhvi
FROM zillow_zhvi
ORDER BY zipcode)
SELECT t1.zipcode, t1.segct, t1.segathct, (t1.segct*t1.segathct)/cast(t2.y_2016 as decimal) as percapita_segusers, t1.segct/cast(t2.y_2016 as decimal) as percapita_segs, t2.y_2016, t3.metro, t3.zhvi as med_price
FROM t1
INNER JOIN t2
ON t1.zipcode = t2.zipcode 
INNER JOIN t3
ON t3.zipcode = t2.zipcode
ORDER BY zipcode DESC;"""

df_all = pd.read_sql_query(query,con=engine)

# %% [markdown]
# | Metro | Zipcodes with segments   |
# |------|------|
# |   New York  | 186|
# |Washington     |          184|
# |Dallas-Fort Worth    |    101|
# |Baltimore            |     95|
# |Philadelphia          |    90|
# |Denver               |     90|
# |Houston  |                 86|
# |Chicago |                  76|
# |Minneapolis-St Paul  |     57|
# |Seattle  |                 49|
# |Austin   |                 47|
# |Portland  |                41|
# |San Diego  |               38|
# |San Antonio  |             37|
# |Charlotte |                29|
# |Raleigh   |                28|
# |Birmingham   |             27|
# |Rochester   |              16|
# |Boulder    |               12|
# |Salisbury  |                9|
# |Buffalo    |                6|
# |Fargo      |                5|
# |Bismarck   |                4|
# |Burlington |                3|
# |Hagerstown  |               2|
# |Ocean City   |              2|
# |York       |                2|
# |Greeley    |                2|
# |Durham      |               2|
# |Miami-Fort Lauderdale   |   1|
# |Tuscaloosa |                1|
# |Atlanta   |                 1|
# |Dover   |                   1|
# |

# %% [markdown]
# 4 metros left after culling
# - Austin
# - Seattle
# - Charlotte
# - Birmingham

# %% [markdown]
# ## Aggregated plots from segment data

# %%
query_austin = """WITH t1 AS (SELECT zipcode, count(zipcode) as segct, sum(segment_details.athlete_count) as segathct
   FROM segment
   INNER JOIN segment_details
   ON segment.seg_id = segment_details.seg_id
   GROUP BY zipcode),
   t2 AS (SELECT zipcode, y_2016
   FROM zipstats),
   t3 AS (SELECT zipcode, metro,zhvi
   FROM zillow_zhvi
   ORDER BY zipcode)
   SELECT t1.zipcode, t1.segct, t1.segathct, (t1.segct*t1.segathct)/cast(t2.y_2016 as decimal) as percapita_segusers, t1.segct/cast(t2.y_2016 as decimal) as percapita_segs, t2.y_2016, t3.metro, t3.zhvi as med_price
   FROM t1
   INNER JOIN t2
   ON t1.zipcode = t2.zipcode 
   INNER JOIN t3
   ON t3.zipcode = t2.zipcode
   WHERE metro = 'Austin'
   ORDER BY zipcode DESC;"""

# %%
def plot_metro(cityname):
    newquery=query_austin.replace('Austin', cityname)
    df = pd.read_sql_query(newquery,con=engine)
    g = sns.jointplot("percapita_segs", "med_price", data=df,xlim=(0, df.max()['percapita_segs']), ylim=(0, df.max()['med_price']), kind="reg", color="r", size=8, ratio=6,space=0.05,marginal_kws=dict(bins=12))
    fig=g.fig
    fig.suptitle('{} Metro Strava segment vs Zillow house prices'.format(cityname), fontsize=18, y=1.05,fontweight='bold')
    g.ax_joint.set_xlabel('Segments per zipcode per capita', fontsize=15)
    g.ax_joint.set_ylabel('Median list price per zipcode', fontsize=15)
    rsquare = lambda a, b: stats.pearsonr(a, b)[0]
    g = g.annotate(rsquare, template="{stat}= {val:.2f}", stat="$PearsonR$", loc="upper left", fontsize=15)
    plt.xlim(0,df.max()['percapita_segs'])
    plt.show()
    return None

# %%
plot_metro('Austin')

# %%
plot_metro('Seattle')

# %%
plot_metro('Charlotte')

# %%
plot_metro('Birmingham')

# %%
HTML('<iframe width="1020px" height="780px" src="https://embed.datausa.io/profile/geo/austin-tx/economy/income_geo?viz=True" frameborder="0" ></iframe>')
# Out:
# <iframe width="1020px" height="780px" src="https://embed.datausa.io/profile/geo/austin-tx/economy/income_geo?viz=True" frameborder="0" ></iframe>

# %%
HTML('<iframe width="1020px" height="780px" src="https://embed.datausa.io/profile/geo/seattle-wa/economy/income_geo?viz=True" frameborder="0" ></iframe>')
# Out:
# <iframe width="1020px" height="780px" src="https://embed.datausa.io/profile/geo/seattle-wa/economy/income_geo?viz=True" frameborder="0" ></iframe>

# %% [markdown]
# - Houston
# - Philadelphia
# - Denver
# - Chicago
# - Baltimore
# - Austin
# - Minneapolis-St Paul
# - Seattle
# - Portland
# - San Antonio
# - San Diego
# - Charlotte
# - Raleigh
# - Birmingham
# - Rochester

# %%
output_notebook()
source = ColumnDataSource(data=df)
hover = HoverTool(tooltips=[
    ("zipcode", "@zipcode")
    ])

p = figure(plot_width=700, plot_height=500, tools=[hover],
           title='Austin Metro strava-zillow plot')

p.circle('percapita_segs', 'med_price', size=7, source=source)
p.xaxis.axis_label='Segments per zipcode per capita'
p.yaxis.axis_label='Median list price per zipcode'
p.xaxis.axis_label_text_font_style = 'bold'
p.yaxis.axis_label_text_font_style = 'bold'
p.xaxis[0].formatter = NumeralTickFormatter(format="0.000")
p.yaxis[0].formatter = NumeralTickFormatter(format="$0,0")
p.title.align = 'center'

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="98d24ff8-99eb-4e96-a970-81d17cb16ee5">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1174b97aa626> in <module>()
#       1 output_notebook()
# ----> 2 source = ColumnDataSource(data=df)
#       3 hover = HoverTool(tooltips=[
#       4     ("zipcode", "@zipcode")
#       5     ])
#
# NameError: name 'df' is not defined
